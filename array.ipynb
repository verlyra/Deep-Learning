# %%
import numpy as np

array1 = np.random.rand(5)

print("Array 1:", array1)
# Out:
# Array 1: [0.36193302 0.62279485 0.97088808 0.07173046 0.49962912]

# %%
import numpy as np
array1 = np.zeros(4)
print(array1)

array2 = np.ones(4)
print(array2)
